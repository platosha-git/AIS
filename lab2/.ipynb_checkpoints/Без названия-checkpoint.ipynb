# %%
import pandas as pd
from pandas_ods_reader import read_ods

ods_path = "./Cities.ods"
dataOds = read_ods(base_path, 1, headers=True)
dataOds.index = dataOds.index + 1

display(dataOds)
# Out:
#                    Город Цель посещения       Вид туризма        Область  \
# 1            Александров         Туризм      Исторический   Владимирская
# 2             Боголюбово  Паломничество      Исторический   Владимирская
# 3                Боровск         Туризм      Исторический      Калужская
# 4       Великий Новгород         Туризм      Исторический   Новгородская
# 5               Владимир         Туризм      Исторический   Владимирская
# 6             Звенигород  Паломничество      Исторический     Московская
# 7             Зеленоград         Туризм  Научный, Пляжный     Московская
# 8                Иваново         Туризм      Исторический     Ивановская
# 9                  Истра         Туризм           Пляжный     Московская
# 10                Казань         Туризм      Исторический      Татарстан
# 11                Калуга         Туризм      Исторический      Калужская
# 12               Коломна         Туризм      Исторический     Московская
# ...

# %%
#Евклидова мера близости

def evklid(id1, id2) {
  sumEvk = 0
  for key in data[id1].signs {
    sumEvk += pow((data[id1] - data[id2]), 2)
  }
    
  return Math.pow(sumEvk, 1/2)
}

# %%
json_path = "./data.json"
dataJson = pd.read_json(json_path, orient='split')

display(pd.factorize(dataJson))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [40], line 4
#       1 json_path = "./data.json"
#       2 dataJson = pd.read_json(json_path, orient='split')
# ----> 4 display(pd.factorize(dataJson))
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/algorithms.py:763, in factorize(values, sort, na_sentinel, size_hint)
#     760     else:
#     761         na_value = None
# --> 763     codes, uniques = factorize_array(
#     764         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     765     )
#     767 if sort and len(uniques) > 0:
#     768     uniques, codes = safe_sort(
#     769         uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     770     )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/algorithms.py:560, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
# ...
